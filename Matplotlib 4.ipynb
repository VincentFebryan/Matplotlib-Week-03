# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %%
mu, sigma = 100 ,15

x = mu + sigma * np.random.randn(10000)
x
# Out:
# array([109.57961016, 103.29623226,  98.51649583, ..., 108.42339227,
#        102.66547191,  81.41933632])

# %%
x.shape
# Out:
# (10000,)

# %%
plt.hist(x, 
        bins=50,
        facecolor='g',
        alpha=0.75)
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45, 500, r'$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()

# %%
fig, ax = plt.subplots()

ax.hist(x,
       bins = 50,
       facecolor = 'r',
       alpha = 0.75)

ax.set_xlabel('Sumbu X')
ax.set_ylabel('Sumbu Y')
ax.set_title('Contoh Histogram')

ax.text(45, 500, r'$\mu=100,\ \sigma=15$')
ax.grid()
        
plt.show()
